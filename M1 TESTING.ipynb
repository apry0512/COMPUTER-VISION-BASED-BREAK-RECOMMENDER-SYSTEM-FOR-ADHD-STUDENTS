# %% [markdown]
# <a href="https://colab.research.google.com/github/apry0512/COMPUTER-VISION-BASED-BREAK-RECOMMENDER-SYSTEM-FOR-ADHD-STUDENTS/blob/main/M1%20TESTING.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Flow-Aware Movement Break Recommender for Students with ADHD
# ### MediaPipe Pose Pipeline
#
# **Researcher:** Aparajita Singh
# **Student Number:** 3539316
# **Supervisor:** Professor Kevin Swingler
# **Ethics Reference:** GUEP 2026 26874 21008
# **MSc Advanced Computing with Artificial Intelligence — University of Stirling**
#
#
#
# ## Pipeline Overview
#
# ```
# Video Upload → MediaPipe Pose → Keypoint Extraction → Feature Engineering
#      → Three-State Classification (Restless / Neutral / Flow)
#      → Flow Protection Logic → Break Recommendation
# ```
#
#
#
# | Phase | Description |
# |---|---|
# | 1 | Install dependencies |
# | 2 | Upload video and state log |
# | 3 | Run MediaPipe Pose — extract keypoints |
# | 4 | Merge keypoints with state labels |
# | 5 | Feature engineering over rolling windows |
# | 6 | Train and evaluate three-state classifier |
# | 7 | Testing if the system works |

# %% [markdown]
# # **PART-1**
# ## TRAINING THE MODEL

# %% [markdown]
# ## Phase 1 — Install Dependencies
#
# Installs MediaPipe, OpenCV, and supporting libraries.
# **Run this cell first every time you open the notebook.**

# %%
# !pip install mediapipe opencv-python-headless pandas numpy scikit-learn matplotlib seaborn -q
print("Install complete")
# Out:
# Install complete

# %%
import cv2
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
import urllib.request
import warnings
warnings.filterwarnings('ignore')

import mediapipe as mp

from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from sklearn.preprocessing import LabelEncoder, StandardScaler
from google.colab import drive, files

print(f"MediaPipe {mp.__version__} loaded successfully")
# Out:
# MediaPipe 1.0.0 loaded successfully

# %% [markdown]
# ## Phase 2 — Upload Files
#
# You need two files:
#
# **1. Video file** (MP4, minimum 720p)
# Your study session recording. Phone or laptop camera. Full upper body visible.
#
# **2. State log CSV** — a simple CSV with your self-reported state labels.
# Format:
# ```
# timestamp_seconds,state
# 0,N
# 420,F
# 2100,R
# 2700,N
# 3300,F
# ```
# States: **R** = Restless | **N** = Neutral | **F** = Flow
#
# > 💡 **Tip:** Convert your HH:MM timestamps to seconds.
# > Example: 00:07 = 420 seconds, 00:35 = 2100 seconds

# %%
drive.mount('/content/drive')
print("Drive mounted")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Drive mounted

# %%
VIDEO_PATH = '/content/drive/MyDrive/Colab Notebooks/Dissertation Training Recording/Training session 5.mov'

if os.path.exists(VIDEO_PATH):
    cap = cv2.VideoCapture(VIDEO_PATH)
    fps = cap.get(cv2.CAP_PROP_FPS)
    frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
    w = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    h = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    cap.release()
    print(f"Video found: {w}x{h}, {fps:.0f}fps, {frames/fps/60:.1f} mins")
else:
    print(f"ERROR: Video not found at {VIDEO_PATH}")
    print("Check the path is correct")
# Out:
# Video found: 1620x1080, 30fps, 31.0 mins

# %%
# R = Restless, N = Neutral, F = Flow
# Example: if you felt neutral for first 5 mins, flow from 5-20 mins, restless 20-25 mins etc

state_data = {
    'timestamp_seconds': [0, 300, 600, 900, 1200, 1500, 1800],
    'state':             ['N', 'R', 'R', 'R', 'F', 'F', 'F']
}

state_log = pd.DataFrame(state_data)
state_log.to_csv('state_log.csv', index=False)
print("State log saved:")
print(state_log)
# Out:
# State log saved:
#    timestamp_seconds state
# 0                  0     N
# 1                300     R
# 2                600     R
# 3                900     R
# 4               1200     F
# 5               1500     F
# 6               1800     F

# %% [markdown]
# ## Phase 3 — Run MediaPipe Pose Extraction
#
# Processes the video frame by frame using MediaPipe Pose.
# Extracts **33 body landmarks** (x, y, z coordinates + visibility) per frame.
# Saves everything to a keypoints CSV.
#
# > ⏱ **Processing time:** Approximately 1-2 minutes per minute of video in Colab.
# > A 90-minute session will take roughly 90-180 minutes to process.
# > Consider using a shorter test clip first to verify everything works.

# %%
MODEL_PATH = 'pose_landmarker_full.task'
if not os.path.exists(MODEL_PATH):
    print("Downloading pose model (about 30MB, takes ~1 min)...")
    urllib.request.urlretrieve(
        'https://storage.googleapis.com/mediapipe-models/pose_landmarker/pose_landmarker_full/float16/latest/pose_landmarker_full.task',
        MODEL_PATH
    )
    print("Model downloaded")
else:
    print("Model already downloaded")
# Out:
# Model already downloaded

# %%
BaseOptions = mp.tasks.BaseOptions
PoseLandmarker = mp.tasks.vision.PoseLandmarker
PoseLandmarkerOptions = mp.tasks.vision.PoseLandmarkerOptions
VisionRunningMode = mp.tasks.vision.RunningMode

LANDMARK_NAMES = [
    'nose', 'left_eye_inner', 'left_eye', 'left_eye_outer',
    'right_eye_inner', 'right_eye', 'right_eye_outer',
    'left_ear', 'right_ear', 'mouth_left', 'mouth_right',
    'left_shoulder', 'right_shoulder', 'left_elbow', 'right_elbow',
    'left_wrist', 'right_wrist', 'left_pinky', 'right_pinky',
    'left_index', 'right_index', 'left_thumb', 'right_thumb',
    'left_hip', 'right_hip', 'left_knee', 'right_knee',
    'left_ankle', 'right_ankle', 'left_heel', 'right_heel',
    'left_foot_index', 'right_foot_index'
]

columns = ['frame', 'timestamp_seconds', 'detected']
for name in LANDMARK_NAMES:
    columns += [f'{name}_x', f'{name}_y', f'{name}_z', f'{name}_vis']

# FRAME_SKIP: process every Nth frame
# 15 = ~2fps from 30fps video. Faster but less data.
# 5 = ~6fps. Slower but more data. Use for short videos.
FRAME_SKIP = 15

options = PoseLandmarkerOptions(
    base_options=BaseOptions(model_asset_path=MODEL_PATH),
    running_mode=VisionRunningMode.VIDEO
)

cap = cv2.VideoCapture(VIDEO_PATH)
fps = cap.get(cv2.CAP_PROP_FPS)
total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
print(f"Processing {total_frames/fps/60:.1f} min video at 1 frame per {FRAME_SKIP} frames...")

rows = []
frame_idx = 0
detected = 0
failed = 0

with PoseLandmarker.create_from_options(options) as landmarker:
    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            break

        if frame_idx % FRAME_SKIP == 0:
            ts_ms = int((frame_idx / fps) * 1000)
            ts_sec = round(frame_idx / fps, 3)

            rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
            mp_img = mp.Image(image_format=mp.ImageFormat.SRGB, data=rgb)
            result = landmarker.detect_for_video(mp_img, ts_ms)

            if result.pose_landmarks and len(result.pose_landmarks) > 0:
                detected += 1
                row = [frame_idx, ts_sec, 1]
                for lm in result.pose_landmarks[0]:
                    row += [round(lm.x, 6), round(lm.y, 6), round(lm.z, 6), round(lm.presence, 4)]
            else:
                failed += 1
                row = [frame_idx, ts_sec, 0] + [None] * (33 * 4)
            rows.append(row)

            processed = frame_idx // FRAME_SKIP
            if processed % 300 == 0 and processed > 0:
                pct = frame_idx / total_frames * 100
                print(f"  {pct:.0f}% done ({processed} frames processed)")

        frame_idx += 1

cap.release()

keypoints_df = pd.DataFrame(rows, columns=columns)
keypoints_df.to_csv('keypoints_raw.csv', index=False)

rate = detected / (detected + failed) * 100 if (detected + failed) > 0 else 0
print(f"\nDone! {detected} frames detected, {failed} failed ({rate:.1f}% detection rate)")
print("Saved: keypoints_raw.csv")
if rate < 70:
    print("WARNING: Detection rate low - check your lighting next time")
# Out:
# Processing 31.0 min video at 1 frame per 15 frames...
#   8% done (300 frames processed)
#   16% done (600 frames processed)
#   24% done (900 frames processed)
#   32% done (1200 frames processed)
#   40% done (1500 frames processed)
#   48% done (1800 frames processed)
#   57% done (2100 frames processed)
#   65% done (2400 frames processed)
#   73% done (2700 frames processed)
#   81% done (3000 frames processed)
#   89% done (3300 frames processed)
#   97% done (3600 frames processed)
#
# Done! 3715 frames detected, 0 failed (100.0% detection rate)
# Saved: keypoints_raw.csv

# %% [markdown]
# ## Phase 4 — Merge Keypoints with State Labels
#
# Matches each keypoint frame to the correct self-reported state label
# based on the timestamps in your state log.
# Produces a single labelled dataset ready for feature engineering.

# %%
def assign_state(ts, log):
    state = 'N'
    for _, row in log.sort_values('timestamp_seconds').iterrows():
        if ts >= row['timestamp_seconds']:
            state = row['state']
        else:
            break
    return state

state_log = pd.read_csv('state_log.csv')
keypoints_df = pd.read_csv('keypoints_raw.csv')

keypoints_df['state'] = keypoints_df['timestamp_seconds'].apply(
    lambda t: assign_state(t, state_log)
)

labelled = keypoints_df.dropna(subset=['nose_x']).copy()
labelled.to_csv('keypoints_labelled.csv', index=False)

print(f"Labelled dataset: {len(labelled)} frames")
print(labelled['state'].value_counts())
# Out:
# Labelled dataset: 3715 frames
# state
# R    1800
# F    1315
# N     600
# Name: count, dtype: int64

# %% [markdown]
# ## Phase 5 — Feature Engineering
#
# Converts raw keypoint coordinates into meaningful signals over rolling time windows.
#
# | Feature | Description | Why it matters |
# |---|---|---|
# | **Movement entropy** | Variance of keypoint positions over window | High = restless, Low = flow |
# | **Postural stability** | Spine angle consistency (shoulders → hips) | Collapse = restless, Stable = flow |
# | **Fidget frequency** | High-freq, low-amplitude oscillation in wrists/ankles | Fidgeting = restless |
# | **Keypoint velocity** | Speed of movement between frames | Erratic spikes = restless |
# | **Gaze proxy** | Head turning frequency | Frequent turns = attention wandering |
# | **Symmetry score** | Left-right body asymmetry | Asymmetric = restless |
# | **Session drift** | Upper body centroid displacement | Drifting = disengagement |
#
# > **Rolling window size:** 30 seconds (adjustable below). Features computed per window, not per frame.

# %%
labelled = pd.read_csv('keypoints_labelled.csv')

WINDOW_SEC = 30
STEP_SEC = 5

def entropy(df, col):
    return df[col].var() if not df[col].isna().all() else 0

def velocity(df, col):
    return df[col].diff().abs().mean() if not df[col].isna().all() else 0

def postural_stability(df):
    sx = (df['left_shoulder_x'] + df['right_shoulder_x']) / 2
    sy = (df['left_shoulder_y'] + df['right_shoulder_y']) / 2
    hx = (df['left_hip_x'] + df['right_hip_x']) / 2
    hy = (df['left_hip_y'] + df['right_hip_y']) / 2
    angles = np.arctan2(hy - sy, hx - sx)
    return angles.var() if not np.isnan(angles.var()) else 0

max_time = labelled['timestamp_seconds'].max()
rows = []

for start in np.arange(0, max_time - WINDOW_SEC, STEP_SEC):
    end = start + WINDOW_SEC
    w = labelled[(labelled['timestamp_seconds'] >= start) & (labelled['timestamp_seconds'] < end)]
    if len(w) < 5:
        continue
    rows.append({
        'window_start': start,
        'entropy_nose': entropy(w, 'nose_x') + entropy(w, 'nose_y'),
        'entropy_left_wrist': entropy(w, 'left_wrist_x') + entropy(w, 'left_wrist_y'),
        'entropy_right_wrist': entropy(w, 'right_wrist_x') + entropy(w, 'right_wrist_y'),
        'entropy_shoulders': entropy(w, 'left_shoulder_x') + entropy(w, 'right_shoulder_x'),
        'postural_stability': postural_stability(w),
        'velocity_nose': velocity(w, 'nose_x'),
        'velocity_left_wrist': velocity(w, 'left_wrist_x'),
        'velocity_right_wrist': velocity(w, 'right_wrist_x'),
        'gaze_proxy': velocity(w, 'nose_x'),
        'symmetry': abs(entropy(w, 'left_wrist_x') - entropy(w, 'right_wrist_x')),
        'state': w['state'].mode()[0]
    })

features = pd.DataFrame(rows)
features.to_csv('features.csv', index=False)
print(f"Feature windows: {len(features)}")
print(features['state'].value_counts())
# Out:
# Feature windows: 366
# state
# R    179
# F    129
# N     58
# Name: count, dtype: int64

# %% [markdown]
# ## Phase 6 — Three-State Classifier Training & Evaluation
#
# Trains two candidate classifiers — **Random Forest** and **SVM** — and evaluates both.
# The better-performing model is selected as the system classifier.
#
# **Target classes:**
# - 🔴 **R** — Restless (hyperactivity buildup — suggest break)
# - 🟡 **N** — Neutral (monitoring — no action)
# - 🟠 **F** — Flow (hyperfocus — suppress prompts, protect session)

# %%
import os

base = '/content/drive/MyDrive/Colab Notebooks/Dissertation Training Recording/'

for root, dirs, files in os.walk(base):
    for f in files:
        if 'feature' in f.lower() or 'features' in f.lower():
            print(os.path.join(root, f))
# Out:
# /content/drive/MyDrive/Colab Notebooks/Dissertation Training Recording/RESULTS SESSION 1/features TS1.csv
# /content/drive/MyDrive/Colab Notebooks/Dissertation Training Recording/RESULTS SESSION 2/features TS2.csv
# /content/drive/MyDrive/Colab Notebooks/Dissertation Training Recording/RESULTS SESSION 3/features TS3.csv
# /content/drive/MyDrive/Colab Notebooks/Dissertation Training Recording/RESULTS SESSION 4/features TS4.csv
# /content/drive/MyDrive/Colab Notebooks/Dissertation Training Recording/RESULTS SESSION 5/features TS5.csv
# /content/drive/MyDrive/Colab Notebooks/Dissertation Training Recording/COMBINED RESULT (1,2,3,4,5)/features.csv

# %%
# Combine all training sessions
DRIVE_BASE = '/content/drive/MyDrive/Colab Notebooks/Dissertation Training Recording/'

session_files = {
    'TS1': DRIVE_BASE + 'RESULTS SESSION 1/features TS1.csv',
    'TS2': DRIVE_BASE + 'RESULTS SESSION 2/features TS2.csv',
    'TS3': DRIVE_BASE + 'RESULTS SESSION 3/features TS3.csv',
    'TS4': DRIVE_BASE + 'RESULTS SESSION 4/features TS4.csv',
    'TS5': DRIVE_BASE + 'RESULTS SESSION 5/features TS5.csv',
}

dfs = []
for name, path in session_files.items():
    if os.path.exists(path):
        df = pd.read_csv(path)
        df['session'] = name
        dfs.append(df)
        print(f'Loaded {name}: {len(df)} windows | {dict(df["state"].value_counts())}')
    else:
        print(f'Not found: {path}')

if dfs:
    combined = pd.concat(dfs, ignore_index=True)
    combined.to_csv('features.csv', index=False)
    print(f'\nCombined: {len(combined)} windows from {len(dfs)} sessions')
    print(combined['state'].value_counts())
else:
    print('No session files found — using existing features.csv')
# Out:
# Loaded TS1: 572 windows | {'F': np.int64(242), 'N': np.int64(178), 'R': np.int64(152)}
# Loaded TS2: 611 windows | {'N': np.int64(252), 'F': np.int64(241), 'R': np.int64(118)}
# Loaded TS3: 365 windows | {'N': np.int64(184), 'F': np.int64(181)}
# Loaded TS4: 241 windows | {'F': np.int64(125), 'N': np.int64(116)}
# Loaded TS5: 366 windows | {'R': np.int64(179), 'F': np.int64(129), 'N': np.int64(58)}
#
# Combined: 2155 windows from 5 sessions
# state
# F    918
# N    788
# R    449
# Name: count, dtype: int64

# %%
features = pd.read_csv('features.csv')

FEATURE_COLS = [
    'entropy_nose', 'entropy_left_wrist', 'entropy_right_wrist',
    'entropy_shoulders', 'postural_stability', 'velocity_nose',
    'velocity_left_wrist', 'velocity_right_wrist', 'gaze_proxy', 'symmetry'
]

X = features[FEATURE_COLS].fillna(0)
y = features['state']

le = LabelEncoder()
y_enc = le.fit_transform(y)

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

X_train, X_test, y_train, y_test = train_test_split(
    X_scaled, y_enc, test_size=0.2, random_state=42, stratify=y_enc
)

# Random Forest
rf = RandomForestClassifier(n_estimators=100, random_state=42, class_weight='balanced')
rf.fit(X_train, y_train)
rf_acc = accuracy_score(y_test, rf.predict(X_test))
rf_cv = cross_val_score(rf, X_scaled, y_enc, cv=5).mean()

# SVM
svm = SVC(kernel='rbf', random_state=42, class_weight='balanced')
svm.fit(X_train, y_train)
svm_acc = accuracy_score(y_test, svm.predict(X_test))
svm_cv = cross_val_score(svm, X_scaled, y_enc, cv=5).mean()

print(f"Random Forest - Test: {rf_acc*100:.1f}%, CV: {rf_cv*100:.1f}%")
print(f"SVM           - Test: {svm_acc*100:.1f}%, CV: {svm_cv*100:.1f}%")

best = rf if rf_cv >= svm_cv else svm
best_name = 'Random Forest' if rf_cv >= svm_cv else 'SVM'
best_pred = best.predict(X_test)
best_acc = rf_acc if rf_cv >= svm_cv else svm_acc

print(f"\nBest model: {best_name}")
print(f"Target: 70% | Achieved: {best_acc*100:.1f}% {'PASSED' if best_acc >= 0.7 else 'BELOW TARGET'}")
print("\n" + classification_report(y_test, best_pred, target_names=le.classes_))
# Out:
# Random Forest - Test: 83.8%, CV: 32.8%
# SVM           - Test: 58.9%, CV: 25.8%
#
# Best model: Random Forest
# Target: 70% | Achieved: 83.8% PASSED
#
#               precision    recall  f1-score   support
#
#            F       0.80      0.92      0.86       184
#            N       0.85      0.81      0.83       157
#            R       0.92      0.72      0.81        90
#
#     accuracy                           0.84       431
#    macro avg       0.86      0.82      0.83       431
# weighted avg       0.84      0.84      0.84       431

# %%
cm = confusion_matrix(y_test, best_pred)
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

sns.heatmap(cm, annot=True, fmt='d', cmap='Oranges',
            xticklabels=le.classes_, yticklabels=le.classes_, ax=axes[0])
axes[0].set_title(f'{best_name} - Confusion Matrix')
axes[0].set_ylabel('True')
axes[0].set_xlabel('Predicted')

if best_name == 'Random Forest':
    pd.Series(best.feature_importances_, index=FEATURE_COLS).sort_values().plot(
        kind='barh', ax=axes[1], color='PINK')
    axes[1].set_title('Feature Importance')

plt.tight_layout()
plt.savefig('classifier_results.png', dpi=150, bbox_inches='tight')
plt.show()
print("Saved: classifier_results.png")
# Out:
# Saved: classifier_results.png

# %%
# State Prediction Smoothing
# Raw per-window predictions flicker heavily (roughly 1 in 3-3.7 windows
# switches state vs. the previous window), because the classifier decides
# independently every window with no temporal context. This applies
# hysteresis smoothing: a new state must be observed for `min_dwell`
# consecutive windows before it's accepted, preventing single-window
# blips from flipping the reported state.

def hysteresis_smooth(states, min_dwell=3):
    """Require min_dwell consecutive windows agreeing before accepting a state change."""
    states = list(states)
    if not states:
        return []
    smoothed = [states[0]]
    current = states[0]
    candidate = states[0]
    candidate_count = 0
    for s in states[1:]:
        if s == current:
            candidate = current
            candidate_count = 0
        else:
            if s == candidate:
                candidate_count += 1
            else:
                candidate = s
                candidate_count = 1
            if candidate_count >= min_dwell:
                current = candidate
                candidate_count = 0
        smoothed.append(current)
    return smoothed

# %% [markdown]
# ## Phase 7 — Flow Protection Logic
#
# Simulates the flow protection mechanism on the classified windows.
# This is the novel contribution — the system decides **when NOT to intervene**.
#
# **Rules:**
# 1. If **FLOW** detected → enter suppression mode, block break prompts
# 2. If **RESTLESS** detected during suppression → only trigger if sustained for `RESTLESS_THRESHOLD` consecutive windows
# 3. If in flow for more than `HYPERFOCUS_SAFEGUARD` seconds → override and suggest break regardless
# 4. If **RESTLESS** outside suppression → trigger break prompt immediately

# %%
RESTLESS_THRESHOLD = 3
HYPERFOCUS_SAFEGUARD = 10800  # 3 hours

all_pred = le.inverse_transform(best.predict(scaler.transform(features[FEATURE_COLS].fillna(0))))
features['predicted'] = all_pred
features['predicted'] = hysteresis_smooth(features['predicted'], min_dwell=3)

in_flow = False
flow_start = None
consecutive_restless = 0
prompts = []
log = []

for _, row in features.iterrows():
    pred = row['predicted']
    ts = row['window_start']
    triggered = False

    if pred == 'F':
        if not in_flow:
            in_flow = True
            flow_start = ts
        consecutive_restless = 0
        if flow_start and (ts - flow_start) >= HYPERFOCUS_SAFEGUARD:
            triggered = True
            in_flow = False
            flow_start = None
            prompts.append({'time_mins': ts/60, 'reason': 'Hyperfocus safeguard (3hrs)'})

    elif pred == 'R':
        if in_flow:
            consecutive_restless += 1
            if consecutive_restless >= RESTLESS_THRESHOLD:
                triggered = True
                in_flow = False
                flow_start = None
                consecutive_restless = 0
                prompts.append({'time_mins': ts/60, 'reason': 'Sustained restlessness during flow'})
        else:
            triggered = True
            prompts.append({'time_mins': ts/60, 'reason': 'Restlessness detected'})

    elif pred == 'N':
        in_flow = False
        flow_start = None
        consecutive_restless = 0

    log.append({'ts': ts, 'pred': pred, 'in_flow': in_flow, 'triggered': triggered})

log_df = pd.DataFrame(log)
prompts_df = pd.DataFrame(prompts) if prompts else pd.DataFrame(columns=['time_mins', 'reason'])

print(f"Break prompts triggered: {len(prompts_df)}")
if len(prompts_df) > 0:
    for _, p in prompts_df.iterrows():
        print(f"  {p['time_mins']:.1f} mins - {p['reason']}")

# Timeline plot
fig, ax = plt.subplots(figsize=(16, 3))
colors = {'R': '#cc3214', 'N': '#4a9e4a', 'F': '#E87722'}
for _, row in log_df.iterrows():
    ax.barh(0, 5, left=row['ts']/60,
            color=colors.get(row['pred'], '#666'),
            alpha=0.4 if row['in_flow'] else 0.85, height=0.6)
for _, p in prompts_df.iterrows():
    ax.axvline(p['time_mins'], color='white', linewidth=2, linestyle='--')
ax.set_xlabel('Time (minutes)')
ax.set_title('Session Timeline - Predicted States & Break Prompts')
ax.set_yticks([])
ax.set_facecolor('#1a1a2e')
fig.patch.set_facecolor('#1a1a2e')
ax.xaxis.label.set_color('white')
ax.title.set_color('white')
ax.tick_params(colors='white')
plt.tight_layout()
plt.savefig('session_timeline.png', dpi=150, bbox_inches='tight', facecolor='#1a1a2e')
plt.show()
print("Saved: session_timeline.png")
# Out:
# Break prompts triggered: 430
#   15.2 mins - Sustained restlessness during flow
#   15.2 mins - Restlessness detected
#   15.3 mins - Restlessness detected
#   15.4 mins - Restlessness detected
#   15.5 mins - Restlessness detected
#   15.6 mins - Restlessness detected
#   15.7 mins - Restlessness detected
#   15.8 mins - Restlessness detected
#   15.8 mins - Restlessness detected
#   15.9 mins - Restlessness detected
#   16.0 mins - Restlessness detected
#   16.1 mins - Restlessness detected
#   16.2 mins - Restlessness detected
#   16.2 mins - Restlessness detected
#   16.3 mins - Restlessness detected
#   16.4 mins - Restlessness detected
#   16.5 mins - Restlessness detected
#   16.6 mins - Restlessness detected
#   16.7 mins - Restlessness detected
#   16.8 mins - Restlessness detected
#   16.8 mins - Restlessness detected
#   16.9 mins - Restlessness detected
#   17.0 mins - Restlessness detected
#   17.1 mins - Restlessness detected
#   17.2 mins - Restlessness detected
#   17.2 mins - Restlessness detected
#   17.3 mins - Restlessness detected
#   17.4 mins - Restlessness detected
#   17.5 mins - Restlessness detected
#   17.6 mins - Restlessness detected
#   17.7 mins - Restlessness detected
#   17.8 mins - Restlessness detected
#   17.8 mins - Restlessness detected
#   17.9 mins - Restlessness detected
#   18.0 mins - Restlessness detected
#   18.1 mins - Restlessness detected
#   18.2 mins - Restlessness detected
#   18.2 mins - Restlessness detected
#   18.3 mins - Restlessness detected
#   18.4 mins - Restlessness detected
#   18.5 mins - Restlessness detected
#   18.6 mins - Restlessness detected
#   18.7 mins - Restlessness detected
#   18.8 mins - Restlessness detected
#   18.8 mins - Restlessness detected
#   18.9 mins - Restlessness detected
#   19.0 mins - Restlessness detected
#   19.1 mins - Restlessness detected
#   19.2 mins - Restlessness detected
#   19.2 mins - Restlessness detected
#   19.3 mins - Restlessness detected
#   19.4 mins - Restlessness detected
#   19.5 mins - Restlessness detected
#   19.6 mins - Restlessness detected
#   19.7 mins - Restlessness detected
#   19.8 mins - Restlessness detected
#   19.8 mins - Restlessness detected
#   35.2 mins - Sustained restlessness during flow
#   35.3 mins - Restlessness detected
#   35.4 mins - Restlessness detected
#   35.5 mins - Restlessness detected
#   35.6 mins - Restlessness detected
#   35.7 mins - Restlessness detected
#   35.8 mins - Restlessness detected
#   35.8 mins - Restlessness detected
#   35.9 mins - Restlessness detected
#   36.0 mins - Restlessness detected
#   36.1 mins - Restlessness detected
#   36.2 mins - Restlessness detected
#   36.2 mins - Restlessness detected
#   36.3 mins - Restlessness detected
#   36.4 mins - Restlessness detected
#   36.5 mins - Restlessness detected
#   36.6 mins - Restlessness detected
#   36.7 mins - Restlessness detected
#   36.8 mins - Restlessness detected
#   36.8 mins - Restlessness detected
#   36.9 mins - Restlessness detected
#   37.0 mins - Restlessness detected
#   37.1 mins - Restlessness detected
#   37.2 mins - Restlessness detected
#   37.2 mins - Restlessness detected
#   37.3 mins - Restlessness detected
#   37.4 mins - Restlessness detected
#   37.5 mins - Restlessness detected
#   37.6 mins - Restlessness detected
#   37.7 mins - Restlessness detected
#   37.8 mins - Restlessness detected
#   37.8 mins - Restlessness detected
#   37.9 mins - Restlessness detected
#   38.0 mins - Restlessness detected
#   38.1 mins - Restlessness detected
#   38.2 mins - Restlessness detected
#   38.2 mins - Restlessness detected
#   38.3 mins - Restlessness detected
#   38.4 mins - Restlessness detected
#   38.5 mins - Restlessness detected
#   38.6 mins - Restlessness detected
#   38.7 mins - Restlessness detected
#   38.8 mins - Restlessness detected
#   38.8 mins - Restlessness detected
#   38.9 mins - Restlessness detected
#   39.0 mins - Restlessness detected
#   39.1 mins - Restlessness detected
#   39.2 mins - Restlessness detected
#   39.2 mins - Restlessness detected
#   39.3 mins - Restlessness detected
#   39.4 mins - Restlessness detected
#   39.5 mins - Restlessness detected
#   39.6 mins - Restlessness detected
#   39.7 mins - Restlessness detected
#   39.8 mins - Restlessness detected
#   39.8 mins - Restlessness detected
#   45.0 mins - Restlessness detected
#   45.1 mins - Restlessness detected
#   45.2 mins - Restlessness detected
#   45.2 mins - Restlessness detected
#   45.3 mins - Restlessness detected
#   45.4 mins - Restlessness detected
#   45.5 mins - Restlessness detected
#   45.6 mins - Restlessness detected
#   45.7 mins - Restlessness detected
#   45.8 mins - Restlessness detected
#   45.8 mins - Restlessness detected
#   45.9 mins - Restlessness detected
#   46.0 mins - Restlessness detected
#   46.1 mins - Restlessness detected
#   46.2 mins - Restlessness detected
#   46.2 mins - Restlessness detected
#   46.3 mins - Restlessness detected
#   46.4 mins - Restlessness detected
#   46.5 mins - Restlessness detected
#   46.6 mins - Restlessness detected
#   46.7 mins - Restlessness detected
#   46.8 mins - Restlessness detected
#   46.8 mins - Restlessness detected
#   46.9 mins - Restlessness detected
#   47.0 mins - Restlessness detected
#   47.1 mins - Restlessness detected
#   47.2 mins - Restlessness detected
#   47.2 mins - Restlessness detected
#   47.3 mins - Restlessness detected
#   47.4 mins - Restlessness detected
#   47.5 mins - Restlessness detected
#   47.6 mins - Restlessness detected
#   0.0 mins - Restlessness detected
#   0.1 mins - Restlessness detected
#   5.1 mins - Restlessness detected
#   5.2 mins - Restlessness detected
#   5.2 mins - Restlessness detected
#   5.3 mins - Restlessness detected
#   5.4 mins - Restlessness detected
#   5.5 mins - Restlessness detected
#   5.6 mins - Restlessness detected
#   5.7 mins - Restlessness detected
#   5.8 mins - Restlessness detected
#   5.8 mins - Restlessness detected
#   5.9 mins - Restlessness detected
#   6.0 mins - Restlessness detected
#   6.1 mins - Restlessness detected
#   6.2 mins - Restlessness detected
#   6.2 mins - Restlessness detected
#   6.3 mins - Restlessness detected
#   6.4 mins - Restlessness detected
#   6.5 mins - Restlessness detected
#   6.6 mins - Restlessness detected
#   6.7 mins - Restlessness detected
#   6.8 mins - Restlessness detected
#   6.8 mins - Restlessness detected
#   6.9 mins - Restlessness detected
#   7.0 mins - Restlessness detected
#   7.1 mins - Restlessness detected
#   7.2 mins - Restlessness detected
#   7.2 mins - Restlessness detected
#   7.3 mins - Restlessness detected
#   7.4 mins - Restlessness detected
#   7.5 mins - Restlessness detected
#   7.6 mins - Restlessness detected
#   7.7 mins - Restlessness detected
#   7.8 mins - Restlessness detected
#   7.8 mins - Restlessness detected
#   7.9 mins - Restlessness detected
#   8.0 mins - Restlessness detected
#   8.1 mins - Restlessness detected
#   8.2 mins - Restlessness detected
#   8.2 mins - Restlessness detected
#   8.3 mins - Restlessness detected
#   8.4 mins - Restlessness detected
#   8.5 mins - Restlessness detected
#   8.6 mins - Restlessness detected
#   8.7 mins - Restlessness detected
#   8.8 mins - Restlessness detected
#   8.8 mins - Restlessness detected
#   8.9 mins - Restlessness detected
#   9.0 mins - Restlessness detected
#   9.1 mins - Restlessness detected
#   9.2 mins - Restlessness detected
#   9.2 mins - Restlessness detected
#   9.3 mins - Restlessness detected
#   9.4 mins - Restlessness detected
#   9.5 mins - Restlessness detected
#   9.6 mins - Restlessness detected
#   9.7 mins - Restlessness detected
#   9.8 mins - Restlessness detected
#   9.8 mins - Restlessness detected
#   30.2 mins - Sustained restlessness during flow
#   30.2 mins - Restlessness detected
#   30.3 mins - Restlessness detected
#   30.4 mins - Restlessness detected
#   30.5 mins - Restlessness detected
#   30.6 mins - Restlessness detected
#   30.7 mins - Restlessness detected
#   30.8 mins - Restlessness detected
#   30.8 mins - Restlessness detected
#   30.9 mins - Restlessness detected
#   31.0 mins - Restlessness detected
#   31.1 mins - Restlessness detected
#   31.2 mins - Restlessness detected
#   31.2 mins - Restlessness detected
#   31.3 mins - Restlessness detected
#   31.4 mins - Restlessness detected
#   31.5 mins - Restlessness detected
#   31.6 mins - Restlessness detected
#   31.7 mins - Restlessness detected
#   31.8 mins - Restlessness detected
#   31.8 mins - Restlessness detected
#   31.9 mins - Restlessness detected
#   32.0 mins - Restlessness detected
#   32.1 mins - Restlessness detected
#   32.2 mins - Restlessness detected
#   32.2 mins - Restlessness detected
#   32.3 mins - Restlessness detected
#   32.4 mins - Restlessness detected
#   32.5 mins - Restlessness detected
#   32.6 mins - Restlessness detected
#   32.7 mins - Restlessness detected
#   32.8 mins - Restlessness detected
#   32.8 mins - Restlessness detected
#   32.9 mins - Restlessness detected
#   33.0 mins - Restlessness detected
#   33.1 mins - Restlessness detected
#   33.2 mins - Restlessness detected
#   33.2 mins - Restlessness detected
#   33.3 mins - Restlessness detected
#   33.4 mins - Restlessness detected
#   33.5 mins - Restlessness detected
#   33.6 mins - Restlessness detected
#   33.7 mins - Restlessness detected
#   33.8 mins - Restlessness detected
#   33.8 mins - Restlessness detected
#   33.9 mins - Restlessness detected
#   34.0 mins - Restlessness detected
#   34.1 mins - Restlessness detected
#   34.2 mins - Restlessness detected
#   34.2 mins - Restlessness detected
#   34.3 mins - Restlessness detected
#   34.4 mins - Restlessness detected
#   34.5 mins - Restlessness detected
#   34.6 mins - Restlessness detected
#   34.7 mins - Restlessness detected
#   34.8 mins - Restlessness detected
#   34.8 mins - Restlessness detected
#   5.9 mins - Restlessness detected
#   6.0 mins - Restlessness detected
#   6.1 mins - Restlessness detected
#   6.2 mins - Restlessness detected
#   6.2 mins - Restlessness detected
#   6.3 mins - Restlessness detected
#   6.4 mins - Restlessness detected
#   6.5 mins - Restlessness detected
#   6.6 mins - Restlessness detected
#   6.7 mins - Restlessness detected
#   6.8 mins - Restlessness detected
#   6.8 mins - Restlessness detected
#   6.9 mins - Restlessness detected
#   7.0 mins - Restlessness detected
#   7.1 mins - Restlessness detected
#   7.2 mins - Restlessness detected
#   7.2 mins - Restlessness detected
#   7.3 mins - Restlessness detected
#   7.4 mins - Restlessness detected
#   7.5 mins - Restlessness detected
#   7.6 mins - Restlessness detected
#   7.7 mins - Restlessness detected
#   7.8 mins - Restlessness detected
#   7.8 mins - Restlessness detected
#   7.9 mins - Restlessness detected
#   8.0 mins - Restlessness detected
#   8.1 mins - Restlessness detected
#   8.2 mins - Restlessness detected
#   8.2 mins - Restlessness detected
#   8.3 mins - Restlessness detected
#   8.4 mins - Restlessness detected
#   8.5 mins - Restlessness detected
#   8.6 mins - Restlessness detected
#   8.7 mins - Restlessness detected
#   8.8 mins - Restlessness detected
#   8.8 mins - Restlessness detected
#   8.9 mins - Restlessness detected
#   9.0 mins - Restlessness detected
#   9.1 mins - Restlessness detected
#   9.2 mins - Restlessness detected
#   9.2 mins - Restlessness detected
#   9.3 mins - Restlessness detected
#   9.4 mins - Restlessness detected
#   9.5 mins - Restlessness detected
#   9.6 mins - Restlessness detected
#   9.7 mins - Restlessness detected
#   9.8 mins - Restlessness detected
#   9.8 mins - Restlessness detected
#   9.9 mins - Restlessness detected
#   10.0 mins - Restlessness detected
#   10.1 mins - Restlessness detected
#   10.2 mins - Restlessness detected
#   10.2 mins - Restlessness detected
#   10.3 mins - Restlessness detected
#   10.4 mins - Restlessness detected
#   10.5 mins - Restlessness detected
#   10.6 mins - Restlessness detected
#   10.7 mins - Restlessness detected
#   10.8 mins - Restlessness detected
#   10.8 mins - Restlessness detected
#   10.9 mins - Restlessness detected
#   11.0 mins - Restlessness detected
#   11.1 mins - Restlessness detected
#   11.2 mins - Restlessness detected
#   11.2 mins - Restlessness detected
#   11.3 mins - Restlessness detected
#   11.4 mins - Restlessness detected
#   11.5 mins - Restlessness detected
#   11.6 mins - Restlessness detected
#   11.7 mins - Restlessness detected
#   11.8 mins - Restlessness detected
#   11.8 mins - Restlessness detected
#   11.9 mins - Restlessness detected
#   12.0 mins - Restlessness detected
#   12.1 mins - Restlessness detected
#   12.2 mins - Restlessness detected
#   12.2 mins - Restlessness detected
#   12.3 mins - Restlessness detected
#   12.4 mins - Restlessness detected
#   12.5 mins - Restlessness detected
#   12.6 mins - Restlessness detected
#   12.7 mins - Restlessness detected
#   12.8 mins - Restlessness detected
#   12.8 mins - Restlessness detected
#   12.9 mins - Restlessness detected
#   13.0 mins - Restlessness detected
#   13.1 mins - Restlessness detected
#   13.2 mins - Restlessness detected
#   13.2 mins - Restlessness detected
#   13.3 mins - Restlessness detected
#   13.4 mins - Restlessness detected
#   13.5 mins - Restlessness detected
#   13.6 mins - Restlessness detected
#   13.7 mins - Restlessness detected
#   13.8 mins - Restlessness detected
#   13.8 mins - Restlessness detected
#   13.9 mins - Restlessness detected
#   14.0 mins - Restlessness detected
#   14.1 mins - Restlessness detected
#   14.2 mins - Restlessness detected
#   14.2 mins - Restlessness detected
#   14.3 mins - Restlessness detected
#   14.4 mins - Restlessness detected
#   14.5 mins - Restlessness detected
#   14.6 mins - Restlessness detected
#   14.7 mins - Restlessness detected
#   14.8 mins - Restlessness detected
#   14.8 mins - Restlessness detected
#   14.9 mins - Restlessness detected
#   15.0 mins - Restlessness detected
#   15.1 mins - Restlessness detected
#   15.2 mins - Restlessness detected
#   15.2 mins - Restlessness detected
#   15.3 mins - Restlessness detected
#   15.4 mins - Restlessness detected
#   15.5 mins - Restlessness detected
#   15.6 mins - Restlessness detected
#   15.7 mins - Restlessness detected
#   15.8 mins - Restlessness detected
#   15.8 mins - Restlessness detected
#   15.9 mins - Restlessness detected
#   16.0 mins - Restlessness detected
#   16.1 mins - Restlessness detected
#   16.2 mins - Restlessness detected
#   16.2 mins - Restlessness detected
#   16.3 mins - Restlessness detected
#   16.4 mins - Restlessness detected
#   16.5 mins - Restlessness detected
#   16.6 mins - Restlessness detected
#   16.7 mins - Restlessness detected
#   16.8 mins - Restlessness detected
#   16.8 mins - Restlessness detected
#   16.9 mins - Restlessness detected
#   17.0 mins - Restlessness detected
#   17.1 mins - Restlessness detected
#   17.2 mins - Restlessness detected
#   17.2 mins - Restlessness detected
#   17.3 mins - Restlessness detected
#   17.4 mins - Restlessness detected
#   17.5 mins - Restlessness detected
#   17.6 mins - Restlessness detected
#   17.7 mins - Restlessness detected
#   17.8 mins - Restlessness detected
#   17.8 mins - Restlessness detected
#   17.9 mins - Restlessness detected
#   18.0 mins - Restlessness detected
#   18.1 mins - Restlessness detected
#   18.2 mins - Restlessness detected
#   18.2 mins - Restlessness detected
#   18.3 mins - Restlessness detected
#   18.4 mins - Restlessness detected
#   18.5 mins - Restlessness detected
#   18.6 mins - Restlessness detected
#   18.7 mins - Restlessness detected
#   18.8 mins - Restlessness detected
#   18.8 mins - Restlessness detected
#   18.9 mins - Restlessness detected
#   19.0 mins - Restlessness detected
#   19.1 mins - Restlessness detected
#   19.2 mins - Restlessness detected
#   19.2 mins - Restlessness detected
#   19.3 mins - Restlessness detected
#   19.4 mins - Restlessness detected
#   19.5 mins - Restlessness detected
#   19.6 mins - Restlessness detected
#   19.7 mins - Restlessness detected
#   19.8 mins - Restlessness detected
#   19.8 mins - Restlessness detected
# Saved: session_timeline.png

# %%
import random

BREAKS = {
    'mild': [
        'Take a 2-minute stretch — roll your shoulders and neck slowly',
        'Stand up and shake out your hands and arms for 2 minutes',
        'Take 5 deep slow breaths and roll your ankles',
    ],
    'moderate': [
        'Take a 5-minute walk — even just around the room or hallway',
        'Do 10 jumping jacks or march on the spot for 3 minutes',
        'Make a drink and give yourself 5 minutes away from the screen',
    ],
    'post_hyperfocus': [
        'You have been in deep focus a long time — take a proper 10-15 minute break',
        'Step outside for fresh air if you can — even 5 minutes helps',
        'Eat something, drink water, and rest your eyes — you have earned it',
    ]
}

def get_break(reason):
    if 'safeguard' in reason.lower():
        cat = 'post_hyperfocus'
    elif 'sustained' in reason.lower():
        cat = 'moderate'
    else:
        cat = 'mild'
    return cat, random.choice(BREAKS[cat])

print('BREAK RECOMMENDATION SYSTEM — SESSION SUMMARY')

if len(prompts_df) == 0:
    print('No break prompts triggered this session.')
else:
    for i, prompt in prompts_df.iterrows():
        cat, suggestion = get_break(prompt['reason'])
        print(f"\n[{prompt['time_mins']:.1f} min] BREAK RECOMMENDED")
        print(f"Reason : {prompt['reason']}")
        print(f"Type   : {cat.replace('_', ' ').title()}")
        print(f"Do this: {suggestion}")

print(f'\nTotal break prompts: {len(prompts_df)}')
print(features['predicted'].value_counts())
# Out:
# BREAK RECOMMENDATION SYSTEM — SESSION SUMMARY
#
# [15.2 min] BREAK RECOMMENDED
# Reason : Sustained restlessness during flow
# Type   : Moderate
# Do this: Make a drink and give yourself 5 minutes away from the screen
#
# [15.2 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take a 2-minute stretch — roll your shoulders and neck slowly
#
# [15.3 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Stand up and shake out your hands and arms for 2 minutes
#
# [15.4 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Stand up and shake out your hands and arms for 2 minutes
#
# [15.5 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take 5 deep slow breaths and roll your ankles
#
# [15.6 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Stand up and shake out your hands and arms for 2 minutes
#
# [15.7 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take 5 deep slow breaths and roll your ankles
#
# [15.8 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take 5 deep slow breaths and roll your ankles
#
# [15.8 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Stand up and shake out your hands and arms for 2 minutes
#
# [15.9 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Stand up and shake out your hands and arms for 2 minutes
#
# [16.0 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take a 2-minute stretch — roll your shoulders and neck slowly
#
# [16.1 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Stand up and shake out your hands and arms for 2 minutes
#
# [16.2 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Stand up and shake out your hands and arms for 2 minutes
#
# [16.2 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take 5 deep slow breaths and roll your ankles
#
# [16.3 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Stand up and shake out your hands and arms for 2 minutes
#
# [16.4 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take 5 deep slow breaths and roll your ankles
#
# [16.5 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take 5 deep slow breaths and roll your ankles
#
# [16.6 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take a 2-minute stretch — roll your shoulders and neck slowly
#
# [16.7 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take a 2-minute stretch — roll your shoulders and neck slowly
#
# [16.8 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take a 2-minute stretch — roll your shoulders and neck slowly
#
# [16.8 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take 5 deep slow breaths and roll your ankles
#
# [16.9 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take 5 deep slow breaths and roll your ankles
#
# [17.0 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take 5 deep slow breaths and roll your ankles
#
# [17.1 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take 5 deep slow breaths and roll your ankles
#
# [17.2 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take 5 deep slow breaths and roll your ankles
#
# [17.2 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Stand up and shake out your hands and arms for 2 minutes
#
# [17.3 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take a 2-minute stretch — roll your shoulders and neck slowly
#
# [17.4 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Stand up and shake out your hands and arms for 2 minutes
#
# [17.5 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Stand up and shake out your hands and arms for 2 minutes
#
# [17.6 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take 5 deep slow breaths and roll your ankles
#
# [17.7 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take 5 deep slow breaths and roll your ankles
#
# [17.8 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take a 2-minute stretch — roll your shoulders and neck slowly
#
# [17.8 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take a 2-minute stretch — roll your shoulders and neck slowly
#
# [17.9 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take a 2-minute stretch — roll your shoulders and neck slowly
#
# [18.0 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take 5 deep slow breaths and roll your ankles
#
# [18.1 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take a 2-minute stretch — roll your shoulders and neck slowly
#
# [18.2 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take a 2-minute stretch — roll your shoulders and neck slowly
#
# [18.2 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take 5 deep slow breaths and roll your ankles
#
# [18.3 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Stand up and shake out your hands and arms for 2 minutes
#
# [18.4 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take a 2-minute stretch — roll your shoulders and neck slowly
#
# [18.5 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take 5 deep slow breaths and roll your ankles
#
# [18.6 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take 5 deep slow breaths and roll your ankles
#
# [18.7 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take 5 deep slow breaths and roll your ankles
#
# [18.8 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take 5 deep slow breaths and roll your ankles
#
# [18.8 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take 5 deep slow breaths and roll your ankles
#
# [18.9 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take a 2-minute stretch — roll your shoulders and neck slowly
#
# [19.0 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take 5 deep slow breaths and roll your ankles
#
# [19.1 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take a 2-minute stretch — roll your shoulders and neck slowly
#
# [19.2 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Stand up and shake out your hands and arms for 2 minutes
#
# [19.2 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take 5 deep slow breaths and roll your ankles
#
# [19.3 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take 5 deep slow breaths and roll your ankles
#
# [19.4 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Stand up and shake out your hands and arms for 2 minutes
#
# [19.5 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take 5 deep slow breaths and roll your ankles
#
# [19.6 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take a 2-minute stretch — roll your shoulders and neck slowly
#
# [19.7 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Stand up and shake out your hands and arms for 2 minutes
#
# [19.8 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take 5 deep slow breaths and roll your ankles
#
# [19.8 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take 5 deep slow breaths and roll your ankles
#
# [35.2 min] BREAK RECOMMENDED
# Reason : Sustained restlessness during flow
# Type   : Moderate
# Do this: Make a drink and give yourself 5 minutes away from the screen
#
# [35.3 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take a 2-minute stretch — roll your shoulders and neck slowly
#
# [35.4 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take 5 deep slow breaths and roll your ankles
#
# [35.5 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Stand up and shake out your hands and arms for 2 minutes
#
# [35.6 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take 5 deep slow breaths and roll your ankles
#
# [35.7 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take a 2-minute stretch — roll your shoulders and neck slowly
#
# [35.8 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take 5 deep slow breaths and roll your ankles
#
# [35.8 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take 5 deep slow breaths and roll your ankles
#
# [35.9 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Stand up and shake out your hands and arms for 2 minutes
#
# [36.0 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take 5 deep slow breaths and roll your ankles
#
# [36.1 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take a 2-minute stretch — roll your shoulders and neck slowly
#
# [36.2 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Stand up and shake out your hands and arms for 2 minutes
#
# [36.2 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Stand up and shake out your hands and arms for 2 minutes
#
# [36.3 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take a 2-minute stretch — roll your shoulders and neck slowly
#
# [36.4 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take a 2-minute stretch — roll your shoulders and neck slowly
#
# [36.5 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take a 2-minute stretch — roll your shoulders and neck slowly
#
# [36.6 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take 5 deep slow breaths and roll your ankles
#
# [36.7 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take 5 deep slow breaths and roll your ankles
#
# [36.8 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Stand up and shake out your hands and arms for 2 minutes
#
# [36.8 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take a 2-minute stretch — roll your shoulders and neck slowly
#
# [36.9 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take 5 deep slow breaths and roll your ankles
#
# [37.0 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take a 2-minute stretch — roll your shoulders and neck slowly
#
# [37.1 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take 5 deep slow breaths and roll your ankles
#
# [37.2 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take a 2-minute stretch — roll your shoulders and neck slowly
#
# [37.2 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take a 2-minute stretch — roll your shoulders and neck slowly
#
# [37.3 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take 5 deep slow breaths and roll your ankles
#
# [37.4 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Stand up and shake out your hands and arms for 2 minutes
#
# [37.5 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Stand up and shake out your hands and arms for 2 minutes
#
# [37.6 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take 5 deep slow breaths and roll your ankles
#
# [37.7 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take 5 deep slow breaths and roll your ankles
#
# [37.8 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take 5 deep slow breaths and roll your ankles
#
# [37.8 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take a 2-minute stretch — roll your shoulders and neck slowly
#
# [37.9 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take a 2-minute stretch — roll your shoulders and neck slowly
#
# [38.0 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take a 2-minute stretch — roll your shoulders and neck slowly
#
# [38.1 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Stand up and shake out your hands and arms for 2 minutes
#
# [38.2 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Stand up and shake out your hands and arms for 2 minutes
#
# [38.2 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take a 2-minute stretch — roll your shoulders and neck slowly
#
# [38.3 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take a 2-minute stretch — roll your shoulders and neck slowly
#
# [38.4 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take 5 deep slow breaths and roll your ankles
#
# [38.5 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Stand up and shake out your hands and arms for 2 minutes
#
# [38.6 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Stand up and shake out your hands and arms for 2 minutes
#
# [38.7 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take 5 deep slow breaths and roll your ankles
#
# [38.8 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Stand up and shake out your hands and arms for 2 minutes
#
# [38.8 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take a 2-minute stretch — roll your shoulders and neck slowly
#
# [38.9 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take 5 deep slow breaths and roll your ankles
#
# [39.0 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Stand up and shake out your hands and arms for 2 minutes
#
# [39.1 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Stand up and shake out your hands and arms for 2 minutes
#
# [39.2 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take a 2-minute stretch — roll your shoulders and neck slowly
#
# [39.2 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take 5 deep slow breaths and roll your ankles
#
# [39.3 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Stand up and shake out your hands and arms for 2 minutes
#
# [39.4 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take a 2-minute stretch — roll your shoulders and neck slowly
#
# [39.5 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take 5 deep slow breaths and roll your ankles
#
# [39.6 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take a 2-minute stretch — roll your shoulders and neck slowly
#
# [39.7 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take a 2-minute stretch — roll your shoulders and neck slowly
#
# [39.8 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take 5 deep slow breaths and roll your ankles
#
# [39.8 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take a 2-minute stretch — roll your shoulders and neck slowly
#
# [45.0 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Stand up and shake out your hands and arms for 2 minutes
#
# [45.1 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Stand up and shake out your hands and arms for 2 minutes
#
# [45.2 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take a 2-minute stretch — roll your shoulders and neck slowly
#
# [45.2 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take 5 deep slow breaths and roll your ankles
#
# [45.3 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take a 2-minute stretch — roll your shoulders and neck slowly
#
# [45.4 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take a 2-minute stretch — roll your shoulders and neck slowly
#
# [45.5 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take 5 deep slow breaths and roll your ankles
#
# [45.6 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take a 2-minute stretch — roll your shoulders and neck slowly
#
# [45.7 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take a 2-minute stretch — roll your shoulders and neck slowly
#
# [45.8 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take 5 deep slow breaths and roll your ankles
#
# [45.8 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take 5 deep slow breaths and roll your ankles
#
# [45.9 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take 5 deep slow breaths and roll your ankles
#
# [46.0 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take a 2-minute stretch — roll your shoulders and neck slowly
#
# [46.1 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take 5 deep slow breaths and roll your ankles
#
# [46.2 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take 5 deep slow breaths and roll your ankles
#
# [46.2 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Stand up and shake out your hands and arms for 2 minutes
#
# [46.3 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Stand up and shake out your hands and arms for 2 minutes
#
# [46.4 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take 5 deep slow breaths and roll your ankles
#
# [46.5 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take 5 deep slow breaths and roll your ankles
#
# [46.6 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Stand up and shake out your hands and arms for 2 minutes
#
# [46.7 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Stand up and shake out your hands and arms for 2 minutes
#
# [46.8 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Stand up and shake out your hands and arms for 2 minutes
#
# [46.8 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take a 2-minute stretch — roll your shoulders and neck slowly
#
# [46.9 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take 5 deep slow breaths and roll your ankles
#
# [47.0 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take a 2-minute stretch — roll your shoulders and neck slowly
#
# [47.1 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take 5 deep slow breaths and roll your ankles
#
# [47.2 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take 5 deep slow breaths and roll your ankles
#
# [47.2 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Stand up and shake out your hands and arms for 2 minutes
#
# [47.3 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take a 2-minute stretch — roll your shoulders and neck slowly
#
# [47.4 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take 5 deep slow breaths and roll your ankles
#
# [47.5 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take 5 deep slow breaths and roll your ankles
#
# [47.6 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take 5 deep slow breaths and roll your ankles
#
# [0.0 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take a 2-minute stretch — roll your shoulders and neck slowly
#
# [0.1 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take 5 deep slow breaths and roll your ankles
#
# [5.1 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Stand up and shake out your hands and arms for 2 minutes
#
# [5.2 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Stand up and shake out your hands and arms for 2 minutes
#
# [5.2 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Stand up and shake out your hands and arms for 2 minutes
#
# [5.3 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Stand up and shake out your hands and arms for 2 minutes
#
# [5.4 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Stand up and shake out your hands and arms for 2 minutes
#
# [5.5 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Stand up and shake out your hands and arms for 2 minutes
#
# [5.6 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take a 2-minute stretch — roll your shoulders and neck slowly
#
# [5.7 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take 5 deep slow breaths and roll your ankles
#
# [5.8 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take a 2-minute stretch — roll your shoulders and neck slowly
#
# [5.8 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Stand up and shake out your hands and arms for 2 minutes
#
# [5.9 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take a 2-minute stretch — roll your shoulders and neck slowly
#
# [6.0 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take a 2-minute stretch — roll your shoulders and neck slowly
#
# [6.1 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Stand up and shake out your hands and arms for 2 minutes
#
# [6.2 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take 5 deep slow breaths and roll your ankles
#
# [6.2 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Stand up and shake out your hands and arms for 2 minutes
#
# [6.3 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Stand up and shake out your hands and arms for 2 minutes
#
# [6.4 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Stand up and shake out your hands and arms for 2 minutes
#
# [6.5 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take 5 deep slow breaths and roll your ankles
#
# [6.6 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Stand up and shake out your hands and arms for 2 minutes
#
# [6.7 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Stand up and shake out your hands and arms for 2 minutes
#
# [6.8 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take a 2-minute stretch — roll your shoulders and neck slowly
#
# [6.8 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take 5 deep slow breaths and roll your ankles
#
# [6.9 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Stand up and shake out your hands and arms for 2 minutes
#
# [7.0 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take 5 deep slow breaths and roll your ankles
#
# [7.1 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Stand up and shake out your hands and arms for 2 minutes
#
# [7.2 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take 5 deep slow breaths and roll your ankles
#
# [7.2 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Stand up and shake out your hands and arms for 2 minutes
#
# [7.3 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Stand up and shake out your hands and arms for 2 minutes
#
# [7.4 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take a 2-minute stretch — roll your shoulders and neck slowly
#
# [7.5 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Stand up and shake out your hands and arms for 2 minutes
#
# [7.6 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take 5 deep slow breaths and roll your ankles
#
# [7.7 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take a 2-minute stretch — roll your shoulders and neck slowly
#
# [7.8 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take a 2-minute stretch — roll your shoulders and neck slowly
#
# [7.8 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take 5 deep slow breaths and roll your ankles
#
# [7.9 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Stand up and shake out your hands and arms for 2 minutes
#
# [8.0 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take a 2-minute stretch — roll your shoulders and neck slowly
#
# [8.1 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take 5 deep slow breaths and roll your ankles
#
# [8.2 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take a 2-minute stretch — roll your shoulders and neck slowly
#
# [8.2 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take 5 deep slow breaths and roll your ankles
#
# [8.3 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take 5 deep slow breaths and roll your ankles
#
# [8.4 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Stand up and shake out your hands and arms for 2 minutes
#
# [8.5 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take 5 deep slow breaths and roll your ankles
#
# [8.6 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take a 2-minute stretch — roll your shoulders and neck slowly
#
# [8.7 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take 5 deep slow breaths and roll your ankles
#
# [8.8 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take a 2-minute stretch — roll your shoulders and neck slowly
#
# [8.8 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Stand up and shake out your hands and arms for 2 minutes
#
# [8.9 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Stand up and shake out your hands and arms for 2 minutes
#
# [9.0 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Stand up and shake out your hands and arms for 2 minutes
#
# [9.1 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take 5 deep slow breaths and roll your ankles
#
# [9.2 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Stand up and shake out your hands and arms for 2 minutes
#
# [9.2 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take 5 deep slow breaths and roll your ankles
#
# [9.3 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take a 2-minute stretch — roll your shoulders and neck slowly
#
# [9.4 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take a 2-minute stretch — roll your shoulders and neck slowly
#
# [9.5 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take 5 deep slow breaths and roll your ankles
#
# [9.6 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take 5 deep slow breaths and roll your ankles
#
# [9.7 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take 5 deep slow breaths and roll your ankles
#
# [9.8 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take 5 deep slow breaths and roll your ankles
#
# [9.8 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Stand up and shake out your hands and arms for 2 minutes
#
# [30.2 min] BREAK RECOMMENDED
# Reason : Sustained restlessness during flow
# Type   : Moderate
# Do this: Take a 5-minute walk — even just around the room or hallway
#
# [30.2 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Stand up and shake out your hands and arms for 2 minutes
#
# [30.3 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take a 2-minute stretch — roll your shoulders and neck slowly
#
# [30.4 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take 5 deep slow breaths and roll your ankles
#
# [30.5 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take a 2-minute stretch — roll your shoulders and neck slowly
#
# [30.6 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take 5 deep slow breaths and roll your ankles
#
# [30.7 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take 5 deep slow breaths and roll your ankles
#
# [30.8 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take 5 deep slow breaths and roll your ankles
#
# [30.8 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take a 2-minute stretch — roll your shoulders and neck slowly
#
# [30.9 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Stand up and shake out your hands and arms for 2 minutes
#
# [31.0 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take 5 deep slow breaths and roll your ankles
#
# [31.1 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take a 2-minute stretch — roll your shoulders and neck slowly
#
# [31.2 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take 5 deep slow breaths and roll your ankles
#
# [31.2 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take 5 deep slow breaths and roll your ankles
#
# [31.3 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Stand up and shake out your hands and arms for 2 minutes
#
# [31.4 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take a 2-minute stretch — roll your shoulders and neck slowly
#
# [31.5 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take 5 deep slow breaths and roll your ankles
#
# [31.6 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Stand up and shake out your hands and arms for 2 minutes
#
# [31.7 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take a 2-minute stretch — roll your shoulders and neck slowly
#
# [31.8 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take 5 deep slow breaths and roll your ankles
#
# [31.8 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take a 2-minute stretch — roll your shoulders and neck slowly
#
# [31.9 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Stand up and shake out your hands and arms for 2 minutes
#
# [32.0 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take 5 deep slow breaths and roll your ankles
#
# [32.1 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Stand up and shake out your hands and arms for 2 minutes
#
# [32.2 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take 5 deep slow breaths and roll your ankles
#
# [32.2 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Stand up and shake out your hands and arms for 2 minutes
#
# [32.3 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take 5 deep slow breaths and roll your ankles
#
# [32.4 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Stand up and shake out your hands and arms for 2 minutes
#
# [32.5 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Stand up and shake out your hands and arms for 2 minutes
#
# [32.6 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take a 2-minute stretch — roll your shoulders and neck slowly
#
# [32.7 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take a 2-minute stretch — roll your shoulders and neck slowly
#
# [32.8 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take a 2-minute stretch — roll your shoulders and neck slowly
#
# [32.8 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take a 2-minute stretch — roll your shoulders and neck slowly
#
# [32.9 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Stand up and shake out your hands and arms for 2 minutes
#
# [33.0 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take a 2-minute stretch — roll your shoulders and neck slowly
#
# [33.1 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Stand up and shake out your hands and arms for 2 minutes
#
# [33.2 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take 5 deep slow breaths and roll your ankles
#
# [33.2 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take a 2-minute stretch — roll your shoulders and neck slowly
#
# [33.3 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take a 2-minute stretch — roll your shoulders and neck slowly
#
# [33.4 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take a 2-minute stretch — roll your shoulders and neck slowly
#
# [33.5 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take 5 deep slow breaths and roll your ankles
#
# [33.6 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Stand up and shake out your hands and arms for 2 minutes
#
# [33.7 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take a 2-minute stretch — roll your shoulders and neck slowly
#
# [33.8 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take a 2-minute stretch — roll your shoulders and neck slowly
#
# [33.8 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take a 2-minute stretch — roll your shoulders and neck slowly
#
# [33.9 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take 5 deep slow breaths and roll your ankles
#
# [34.0 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take 5 deep slow breaths and roll your ankles
#
# [34.1 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Stand up and shake out your hands and arms for 2 minutes
#
# [34.2 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take 5 deep slow breaths and roll your ankles
#
# [34.2 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Stand up and shake out your hands and arms for 2 minutes
#
# [34.3 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Stand up and shake out your hands and arms for 2 minutes
#
# [34.4 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take 5 deep slow breaths and roll your ankles
#
# [34.5 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take a 2-minute stretch — roll your shoulders and neck slowly
#
# [34.6 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Stand up and shake out your hands and arms for 2 minutes
#
# [34.7 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take a 2-minute stretch — roll your shoulders and neck slowly
#
# [34.8 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take 5 deep slow breaths and roll your ankles
#
# [34.8 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Stand up and shake out your hands and arms for 2 minutes
#
# [5.9 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take a 2-minute stretch — roll your shoulders and neck slowly
#
# [6.0 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Stand up and shake out your hands and arms for 2 minutes
#
# [6.1 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take a 2-minute stretch — roll your shoulders and neck slowly
#
# [6.2 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Stand up and shake out your hands and arms for 2 minutes
#
# [6.2 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take 5 deep slow breaths and roll your ankles
#
# [6.3 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take a 2-minute stretch — roll your shoulders and neck slowly
#
# [6.4 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take a 2-minute stretch — roll your shoulders and neck slowly
#
# [6.5 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take 5 deep slow breaths and roll your ankles
#
# [6.6 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Stand up and shake out your hands and arms for 2 minutes
#
# [6.7 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Stand up and shake out your hands and arms for 2 minutes
#
# [6.8 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take 5 deep slow breaths and roll your ankles
#
# [6.8 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Stand up and shake out your hands and arms for 2 minutes
#
# [6.9 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Stand up and shake out your hands and arms for 2 minutes
#
# [7.0 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take 5 deep slow breaths and roll your ankles
#
# [7.1 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take 5 deep slow breaths and roll your ankles
#
# [7.2 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take a 2-minute stretch — roll your shoulders and neck slowly
#
# [7.2 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Stand up and shake out your hands and arms for 2 minutes
#
# [7.3 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take a 2-minute stretch — roll your shoulders and neck slowly
#
# [7.4 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take 5 deep slow breaths and roll your ankles
#
# [7.5 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take a 2-minute stretch — roll your shoulders and neck slowly
#
# [7.6 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take a 2-minute stretch — roll your shoulders and neck slowly
#
# [7.7 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take 5 deep slow breaths and roll your ankles
#
# [7.8 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Stand up and shake out your hands and arms for 2 minutes
#
# [7.8 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Stand up and shake out your hands and arms for 2 minutes
#
# [7.9 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take 5 deep slow breaths and roll your ankles
#
# [8.0 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take 5 deep slow breaths and roll your ankles
#
# [8.1 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take a 2-minute stretch — roll your shoulders and neck slowly
#
# [8.2 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Stand up and shake out your hands and arms for 2 minutes
#
# [8.2 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take 5 deep slow breaths and roll your ankles
#
# [8.3 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Stand up and shake out your hands and arms for 2 minutes
#
# [8.4 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take a 2-minute stretch — roll your shoulders and neck slowly
#
# [8.5 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Stand up and shake out your hands and arms for 2 minutes
#
# [8.6 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take a 2-minute stretch — roll your shoulders and neck slowly
#
# [8.7 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take a 2-minute stretch — roll your shoulders and neck slowly
#
# [8.8 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take 5 deep slow breaths and roll your ankles
#
# [8.8 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take 5 deep slow breaths and roll your ankles
#
# [8.9 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take 5 deep slow breaths and roll your ankles
#
# [9.0 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Stand up and shake out your hands and arms for 2 minutes
#
# [9.1 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Stand up and shake out your hands and arms for 2 minutes
#
# [9.2 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take a 2-minute stretch — roll your shoulders and neck slowly
#
# [9.2 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Stand up and shake out your hands and arms for 2 minutes
#
# [9.3 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Stand up and shake out your hands and arms for 2 minutes
#
# [9.4 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take 5 deep slow breaths and roll your ankles
#
# [9.5 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Stand up and shake out your hands and arms for 2 minutes
#
# [9.6 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take 5 deep slow breaths and roll your ankles
#
# [9.7 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Stand up and shake out your hands and arms for 2 minutes
#
# [9.8 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take 5 deep slow breaths and roll your ankles
#
# [9.8 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Stand up and shake out your hands and arms for 2 minutes
#
# [9.9 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take a 2-minute stretch — roll your shoulders and neck slowly
#
# [10.0 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Stand up and shake out your hands and arms for 2 minutes
#
# [10.1 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take a 2-minute stretch — roll your shoulders and neck slowly
#
# [10.2 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take 5 deep slow breaths and roll your ankles
#
# [10.2 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take 5 deep slow breaths and roll your ankles
#
# [10.3 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take a 2-minute stretch — roll your shoulders and neck slowly
#
# [10.4 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take a 2-minute stretch — roll your shoulders and neck slowly
#
# [10.5 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take a 2-minute stretch — roll your shoulders and neck slowly
#
# [10.6 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Stand up and shake out your hands and arms for 2 minutes
#
# [10.7 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take a 2-minute stretch — roll your shoulders and neck slowly
#
# [10.8 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take a 2-minute stretch — roll your shoulders and neck slowly
#
# [10.8 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take 5 deep slow breaths and roll your ankles
#
# [10.9 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Stand up and shake out your hands and arms for 2 minutes
#
# [11.0 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take a 2-minute stretch — roll your shoulders and neck slowly
#
# [11.1 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take 5 deep slow breaths and roll your ankles
#
# [11.2 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Stand up and shake out your hands and arms for 2 minutes
#
# [11.2 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take a 2-minute stretch — roll your shoulders and neck slowly
#
# [11.3 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take a 2-minute stretch — roll your shoulders and neck slowly
#
# [11.4 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Stand up and shake out your hands and arms for 2 minutes
#
# [11.5 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Stand up and shake out your hands and arms for 2 minutes
#
# [11.6 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take 5 deep slow breaths and roll your ankles
#
# [11.7 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Stand up and shake out your hands and arms for 2 minutes
#
# [11.8 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take 5 deep slow breaths and roll your ankles
#
# [11.8 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Stand up and shake out your hands and arms for 2 minutes
#
# [11.9 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take a 2-minute stretch — roll your shoulders and neck slowly
#
# [12.0 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take a 2-minute stretch — roll your shoulders and neck slowly
#
# [12.1 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take a 2-minute stretch — roll your shoulders and neck slowly
#
# [12.2 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take a 2-minute stretch — roll your shoulders and neck slowly
#
# [12.2 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take a 2-minute stretch — roll your shoulders and neck slowly
#
# [12.3 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take 5 deep slow breaths and roll your ankles
#
# [12.4 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take a 2-minute stretch — roll your shoulders and neck slowly
#
# [12.5 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take 5 deep slow breaths and roll your ankles
#
# [12.6 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take 5 deep slow breaths and roll your ankles
#
# [12.7 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Stand up and shake out your hands and arms for 2 minutes
#
# [12.8 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Stand up and shake out your hands and arms for 2 minutes
#
# [12.8 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take a 2-minute stretch — roll your shoulders and neck slowly
#
# [12.9 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take a 2-minute stretch — roll your shoulders and neck slowly
#
# [13.0 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take a 2-minute stretch — roll your shoulders and neck slowly
#
# [13.1 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take 5 deep slow breaths and roll your ankles
#
# [13.2 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take 5 deep slow breaths and roll your ankles
#
# [13.2 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Stand up and shake out your hands and arms for 2 minutes
#
# [13.3 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take 5 deep slow breaths and roll your ankles
#
# [13.4 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take 5 deep slow breaths and roll your ankles
#
# [13.5 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Stand up and shake out your hands and arms for 2 minutes
#
# [13.6 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take a 2-minute stretch — roll your shoulders and neck slowly
#
# [13.7 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Stand up and shake out your hands and arms for 2 minutes
#
# [13.8 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take a 2-minute stretch — roll your shoulders and neck slowly
#
# [13.8 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take 5 deep slow breaths and roll your ankles
#
# [13.9 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take a 2-minute stretch — roll your shoulders and neck slowly
#
# [14.0 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take 5 deep slow breaths and roll your ankles
#
# [14.1 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take a 2-minute stretch — roll your shoulders and neck slowly
#
# [14.2 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take a 2-minute stretch — roll your shoulders and neck slowly
#
# [14.2 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take 5 deep slow breaths and roll your ankles
#
# [14.3 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take a 2-minute stretch — roll your shoulders and neck slowly
#
# [14.4 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Stand up and shake out your hands and arms for 2 minutes
#
# [14.5 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Stand up and shake out your hands and arms for 2 minutes
#
# [14.6 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take a 2-minute stretch — roll your shoulders and neck slowly
#
# [14.7 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take 5 deep slow breaths and roll your ankles
#
# [14.8 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Stand up and shake out your hands and arms for 2 minutes
#
# [14.8 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take 5 deep slow breaths and roll your ankles
#
# [14.9 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take 5 deep slow breaths and roll your ankles
#
# [15.0 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take 5 deep slow breaths and roll your ankles
#
# [15.1 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take 5 deep slow breaths and roll your ankles
#
# [15.2 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take a 2-minute stretch — roll your shoulders and neck slowly
#
# [15.2 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take a 2-minute stretch — roll your shoulders and neck slowly
#
# [15.3 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Stand up and shake out your hands and arms for 2 minutes
#
# [15.4 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take 5 deep slow breaths and roll your ankles
#
# [15.5 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take a 2-minute stretch — roll your shoulders and neck slowly
#
# [15.6 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Stand up and shake out your hands and arms for 2 minutes
#
# [15.7 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Stand up and shake out your hands and arms for 2 minutes
#
# [15.8 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take 5 deep slow breaths and roll your ankles
#
# [15.8 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take a 2-minute stretch — roll your shoulders and neck slowly
#
# [15.9 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Stand up and shake out your hands and arms for 2 minutes
#
# [16.0 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Stand up and shake out your hands and arms for 2 minutes
#
# [16.1 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Stand up and shake out your hands and arms for 2 minutes
#
# [16.2 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take a 2-minute stretch — roll your shoulders and neck slowly
#
# [16.2 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take a 2-minute stretch — roll your shoulders and neck slowly
#
# [16.3 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Stand up and shake out your hands and arms for 2 minutes
#
# [16.4 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take a 2-minute stretch — roll your shoulders and neck slowly
#
# [16.5 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take a 2-minute stretch — roll your shoulders and neck slowly
#
# [16.6 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take 5 deep slow breaths and roll your ankles
#
# [16.7 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take a 2-minute stretch — roll your shoulders and neck slowly
#
# [16.8 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Stand up and shake out your hands and arms for 2 minutes
#
# [16.8 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take 5 deep slow breaths and roll your ankles
#
# [16.9 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take a 2-minute stretch — roll your shoulders and neck slowly
#
# [17.0 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take 5 deep slow breaths and roll your ankles
#
# [17.1 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take a 2-minute stretch — roll your shoulders and neck slowly
#
# [17.2 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take a 2-minute stretch — roll your shoulders and neck slowly
#
# [17.2 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take a 2-minute stretch — roll your shoulders and neck slowly
#
# [17.3 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Stand up and shake out your hands and arms for 2 minutes
#
# [17.4 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take a 2-minute stretch — roll your shoulders and neck slowly
#
# [17.5 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Stand up and shake out your hands and arms for 2 minutes
#
# [17.6 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take 5 deep slow breaths and roll your ankles
#
# [17.7 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Stand up and shake out your hands and arms for 2 minutes
#
# [17.8 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take 5 deep slow breaths and roll your ankles
#
# [17.8 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Stand up and shake out your hands and arms for 2 minutes
#
# [17.9 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take a 2-minute stretch — roll your shoulders and neck slowly
#
# [18.0 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take a 2-minute stretch — roll your shoulders and neck slowly
#
# [18.1 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take a 2-minute stretch — roll your shoulders and neck slowly
#
# [18.2 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take a 2-minute stretch — roll your shoulders and neck slowly
#
# [18.2 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Stand up and shake out your hands and arms for 2 minutes
#
# [18.3 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take 5 deep slow breaths and roll your ankles
#
# [18.4 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Stand up and shake out your hands and arms for 2 minutes
#
# [18.5 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take a 2-minute stretch — roll your shoulders and neck slowly
#
# [18.6 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take 5 deep slow breaths and roll your ankles
#
# [18.7 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take 5 deep slow breaths and roll your ankles
#
# [18.8 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take 5 deep slow breaths and roll your ankles
#
# [18.8 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Stand up and shake out your hands and arms for 2 minutes
#
# [18.9 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take a 2-minute stretch — roll your shoulders and neck slowly
#
# [19.0 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take a 2-minute stretch — roll your shoulders and neck slowly
#
# [19.1 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take 5 deep slow breaths and roll your ankles
#
# [19.2 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take 5 deep slow breaths and roll your ankles
#
# [19.2 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take a 2-minute stretch — roll your shoulders and neck slowly
#
# [19.3 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take a 2-minute stretch — roll your shoulders and neck slowly
#
# [19.4 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take 5 deep slow breaths and roll your ankles
#
# [19.5 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take a 2-minute stretch — roll your shoulders and neck slowly
#
# [19.6 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take 5 deep slow breaths and roll your ankles
#
# [19.7 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Stand up and shake out your hands and arms for 2 minutes
#
# [19.8 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take 5 deep slow breaths and roll your ankles
#
# [19.8 min] BREAK RECOMMENDED
# Reason : Restlessness detected
# Type   : Mild
# Do this: Take a 2-minute stretch — roll your shoulders and neck slowly
#
# Total break prompts: 430
# predicted
# F    913
# N    806
# R    436
# Name: count, dtype: int64

# %% [markdown]
# # Phase 8 — Download Results
#
# Downloads all output files to your local machine.

# %%
from google.colab import files as colab_files

import zipfile
output_files = ['keypoints_raw.csv', 'keypoints_labelled.csv',
                'features.csv', 'classifier_results.png', 'session_timeline.png']

with zipfile.ZipFile('results.zip', 'w') as zf:
    for f in output_files:
        if os.path.exists(f):
            zf.write(f)
            print(f"Added: {f}")

colab_files.download('results.zip')
print("Done!")
# Out:
# Added: keypoints_raw.csv
# Added: keypoints_labelled.csv
# Added: features.csv
# Added: classifier_results.png
# Added: session_timeline.png
# Done!

# %% [markdown]
# # **PART-2**
# ## TESTING THE MODEL

# %%
# HELD-OUT / PARTICIPANT TESTING
TEST_VIDEO_PATH = '/content/drive/MyDrive/Colab Notebooks/Dissertation Testing Recording/M1.mp4'

print(f'Processing: {TEST_VIDEO_PATH}')

cap_test = cv2.VideoCapture(TEST_VIDEO_PATH)
fps_test = cap_test.get(cv2.CAP_PROP_FPS)
total_test = int(cap_test.get(cv2.CAP_PROP_FRAME_COUNT))
print(f'Duration: {total_test/fps_test/60:.1f} mins')

test_rows = []
test_frame_idx = 0
test_detected = 0

options_test = PoseLandmarkerOptions(
    base_options=BaseOptions(model_asset_path=MODEL_PATH),
    running_mode=VisionRunningMode.VIDEO
)

with PoseLandmarker.create_from_options(options_test) as lm:
    while cap_test.isOpened():
        ret, frame = cap_test.read()
        if not ret:
            break
        if test_frame_idx % FRAME_SKIP == 0:
            ts_ms = int((test_frame_idx / fps_test) * 1000)
            ts_sec = round(test_frame_idx / fps_test, 3)
            rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
            mp_img = mp.Image(image_format=mp.ImageFormat.SRGB, data=rgb)
            result = lm.detect_for_video(mp_img, ts_ms)
            if result.pose_landmarks and len(result.pose_landmarks) > 0:
                test_detected += 1
                row = [test_frame_idx, ts_sec, 1]
                for lm_pt in result.pose_landmarks[0]:
                    row += [round(lm_pt.x,6), round(lm_pt.y,6),
                            round(lm_pt.z,6), round(lm_pt.presence,4)]
            else:
                row = [test_frame_idx, ts_sec, 0] + [None]*(33*4)
            test_rows.append(row)
        test_frame_idx += 1

cap_test.release()

test_kp_df = pd.DataFrame(test_rows, columns=columns)
det_rate = test_detected/len(test_rows)*100
print(f'Detection rate: {det_rate:.1f}%')

# Feature engineering — no labels
test_feature_rows = []
max_time_test = test_kp_df[test_kp_df['detected']==1]['timestamp_seconds'].max()
test_labelled = test_kp_df.dropna(subset=['nose_x']).copy()

for start in np.arange(0, max_time_test - WINDOW_SEC, STEP_SEC):
    end = start + WINDOW_SEC
    w = test_labelled[(test_labelled['timestamp_seconds'] >= start) &
                      (test_labelled['timestamp_seconds'] < end)]
    if len(w) < 5:
        continue
    try:
        sx = (w['left_shoulder_x'] + w['right_shoulder_x']) / 2
        sy = (w['left_shoulder_y'] + w['right_shoulder_y']) / 2
        hx = (w['left_hip_x'] + w['right_hip_x']) / 2
        hy = (w['left_hip_y'] + w['right_hip_y']) / 2
        post_stab = float(np.arctan2(hy - sy, hx - sx).var())
    except:
        post_stab = 0

    test_feature_rows.append({
        'window_start': start,
        'entropy_nose': w['nose_x'].var() + w['nose_y'].var(),
        'entropy_left_wrist': w['left_wrist_x'].var() + w['left_wrist_y'].var(),
        'entropy_right_wrist': w['right_wrist_x'].var() + w['right_wrist_y'].var(),
        'entropy_shoulders': w['left_shoulder_x'].var() + w['right_shoulder_x'].var(),
        'postural_stability': post_stab,
        'velocity_nose': w['nose_x'].diff().abs().mean(),
        'velocity_left_wrist': w['left_wrist_x'].diff().abs().mean(),
        'velocity_right_wrist': w['right_wrist_x'].diff().abs().mean(),
        'gaze_proxy': w['nose_x'].diff().abs().var(),
        'symmetry': abs(w['left_wrist_x'].var() - w['right_wrist_x'].var()),
    })

test_features = pd.DataFrame(test_feature_rows)

# Predict — model decides everything
X_test = test_features[FEATURE_COLS].fillna(0)
X_test_scaled = scaler.transform(X_test)
predictions = le.inverse_transform(best.predict(X_test_scaled))
test_features['predicted_state'] = predictions
test_features['predicted_state'] = hysteresis_smooth(test_features['predicted_state'], min_dwell=3)

print(f'\n=== SESSION RESULTS ===')
print(pd.Series(predictions).value_counts())
print(f'\nFlow windows (protected): {(predictions == "F").sum()}')
print(f'Neutral windows (monitoring): {(predictions == "N").sum()}')
print(f'Restless windows (break prompted): {(predictions == "R").sum()}')
print(f'\nBreak prompts would have fired: {(predictions == "R").sum()} times')
print(f'Flow protection would have suppressed prompts for: {(predictions == "F").sum()} windows')
# Out:
# Processing: /content/drive/MyDrive/Colab Notebooks/Dissertation Testing Recording/M1.mp4
# Duration: 19.6 mins
# Detection rate: 100.0%
#
# === SESSION RESULTS ===
# N    139
# F     90
# Name: count, dtype: int64
#
# Flow windows (protected): 90
# Neutral windows (monitoring): 139
# Restless windows (break prompted): 0
#
# Break prompts would have fired: 0 times
# Flow protection would have suppressed prompts for: 90 windows

# %%
# Classify held-out session using trained model
X_test = test_features[FEATURE_COLS].fillna(0)
X_test_scaled = scaler.transform(X_test)
predictions = le.inverse_transform(best.predict(X_test_scaled))
test_features['predicted_state'] = predictions

print('M1 SESSION PREDICTIONS')
print(f'Total windows: {len(test_features)}')
print(pd.Series(predictions).value_counts())
print(f'\nFlow windows: {(predictions == "F").sum()}')
print(f'Neutral windows: {(predictions == "N").sum()}')
print(f'Restless windows: {(predictions == "R").sum()}')
# Out:
# M1 SESSION PREDICTIONS
# Total windows: 229
# N    139
# F     90
# Name: count, dtype: int64
#
# Flow windows: 90
# Neutral windows: 139
# Restless windows: 0

# %%
# Save held-out results
import zipfile
with zipfile.ZipFile('M1.zip', 'w') as zf:
    # Save test features with predictions
    test_features.to_csv('test_features_predictions.csv', index=False)
    zf.write('test_features_predictions.csv')
    if os.path.exists('session_timeline.png'):
        zf.write('session_timeline.png', 'M1_timeline.png')
    print('M1 results saved')

colab_files.download('M1.zip')
# Out:
# M1 results saved

# %% [markdown]
# # **PART-3**
# ## REAL TIME INTERFACE

# %%
import mediapipe as mp
import cv2
import numpy as np
from mediapipe.tasks import python
from mediapipe.tasks.python import vision

BaseOptions = mp.tasks.BaseOptions
PoseLandmarker = mp.tasks.vision.PoseLandmarker
PoseLandmarkerOptions = mp.tasks.vision.PoseLandmarkerOptions
VisionRunningMode = mp.tasks.vision.RunningMode

MODEL_PATH = 'pose_landmarker_full.task'

# %%
# Real-Time Webcam Demo
# Captures a live frame from your webcam, runs MediaPipe pose estimation,
# classifies the current state using the trained model, and displays the result

from IPython.display import display, Javascript, Image as IPImage
from google.colab.output import eval_js
from base64 import b64decode
import cv2
import numpy as np

def capture_frame():
    js = Javascript('''
        async function captureFrame() {
            const div = document.createElement('div');
            const btn = document.createElement('button');
            btn.textContent = '📸 Capture frame for classification';
            btn.style.padding = '10px 20px';
            btn.style.fontSize = '16px';
            btn.style.backgroundColor = '#E87722';
            btn.style.color = 'white';
            btn.style.border = 'none';
            btn.style.borderRadius = '5px';
            btn.style.cursor = 'pointer';
            div.appendChild(btn);
            document.body.appendChild(div);

            const video = document.createElement('video');
            video.style.display = 'block';
            video.style.marginTop = '10px';
            const stream = await navigator.mediaDevices.getUserMedia({video: true});
            document.body.appendChild(video);
            video.srcObject = stream;
            await video.play();

            google.colab.output.setIframeHeight(document.documentElement.scrollHeight, true);
            await new Promise((resolve) => btn.onclick = resolve);

            const canvas = document.createElement('canvas');
            canvas.width = video.videoWidth;
            canvas.height = video.videoHeight;
            canvas.getContext('2d').drawImage(video, 0, 0);
            stream.getVideoTracks()[0].stop();
            div.remove();
            video.remove();
            return canvas.toDataURL('image/jpeg', 0.8);
        }
        captureFrame();
    ''')
    display(js)
    data = eval_js('captureFrame()')
    binary = b64decode(data.split(',')[1])
    return binary

print("Real-Time Webcam Classification Demo")
print("Click the button to capture a frame and classify your current state.")
print("Make sure your surroundings are well lit and your upper body is visible.\n")

# Capture frame
img_bytes = capture_frame()

# Convert to numpy array
img_array = np.frombuffer(img_bytes, dtype=np.uint8)
frame = cv2.imdecode(img_array, cv2.IMREAD_COLOR)

# Run MediaPipe on single frame
rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
mp_img = mp.Image(image_format=mp.ImageFormat.SRGB, data=rgb)

options_img = PoseLandmarkerOptions(
    base_options=BaseOptions(model_asset_path=MODEL_PATH),
    running_mode=VisionRunningMode.IMAGE
)

with PoseLandmarker.create_from_options(options_img) as lm:
    result = lm.detect(mp_img)

if result.pose_landmarks and len(result.pose_landmarks) > 0:
    # Draw landmarks on frame
    for lm_pt in result.pose_landmarks[0]:
        x = int(lm_pt.x * frame.shape[1])
        y = int(lm_pt.y * frame.shape[0])
        cv2.circle(frame, (x, y), 5, (0, 165, 255), -1)

    # Use most recent predicted state from training pipeline
    # Note: single frame cannot be classified directly — needs 30s window
    # This demo shows real-time pose detection working on live webcam input
    state_label = {'F': 'FLOW', 'N': 'NEUTRAL', 'R': 'RESTLESS'}.get(
    globals().get('current_state', 'N'), 'DETECTING')
    colour = {'FLOW': (0,180,0), 'NEUTRAL': (0,165,255), 'RESTLESS': (0,0,220)}.get(
        state_label, (128,128,128))

    # Draw state overlay
    cv2.rectangle(frame, (10,10), (350,65), (0,0,0), -1)
    cv2.rectangle(frame, (10,10), (350,65), colour, 3)
    cv2.putText(frame, f'Detected State: {state_label}', (20,50),
                cv2.FONT_HERSHEY_SIMPLEX, 0.9, colour, 2)

    # Add landmark count
    cv2.putText(frame, f'Landmarks: {len(result.pose_landmarks[0])}/33 detected',
                (10, frame.shape[0]-15),
                cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255,255,255), 1)

    # Display result
    _, buffer = cv2.imencode('.jpg', frame)
    display(IPImage(data=buffer.tobytes()))

    print(f"\n Pose detection successful!")
    print(f"   Landmarks detected: {len(result.pose_landmarks[0])}/33")
    print(f"   Current system state: {state_label}")
    print(f"\nNote: Live state classification uses 30-second rolling windows.")
    print(f"This demo confirms the MediaPipe pipeline works on live webcam input.")
    print(f"In a full deployment, the system would continuously classify")
    print(f"rolling windows and apply flow protection logic in real time.")

else:
    print("No pose detected in frame.")
    print("Please ensure:")
    print("  • Your upper body is clearly visible")
    print("  • Lighting is frontal (not behind you)")
    print("  • You are within 1-2 metres of the camera")
# Out:
# Real-Time Webcam Classification Demo
# Click the button to capture a frame and classify your current state.
# Make sure your surroundings are well lit and your upper body is visible.
#  Pose detection successful!
#    Landmarks detected: 33/33
#    Current system state: NEUTRAL
#
# Note: Live state classification uses 30-second rolling windows.
# This demo confirms the MediaPipe pipeline works on live webcam input.
# In a full deployment, the system would continuously classify
# rolling windows and apply flow protection logic in real time.
